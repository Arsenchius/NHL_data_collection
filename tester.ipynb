# %%
import json
import pandas as pd

table = pd.read_json('data/table.json')
table
# Out:
#             team  pos  tm  tw  twr  two  tl  tlr  tlo   sg   cg  tp division
# 0       Виннипег    1  48  31   24    7  17   16    1  159  126  63     West
# 1         Даллас    2  48  28   25    2  20   13    5  167  124  63     West
# 2          Вегас    3  48  29   21    5  19   17    1  156  139  60     West
# 3          Сиэтл    4  46  27   22    5  19   14    3  166  144  59     West
# 4   Лос-Анджелес    5  49  26   19    3  23   17    5  159  167  58     West
# 5       Эдмонтон    6  48  27   25    2  21   18    2  178  156  57     West
# 6      Миннесота    7  45  25   20    2  20   16    2  143  130  54     West
# 7       Колорадо    8  45  25   16    5  20   17    1  141  124  53     West
# 8        Калгари    9  47  22   19    2  25   16    6  147  142  53     West
# 9        Нэшвилл   10  46  22   17    3  24   18    5  129  136  50     West
# 10     Сент-Луис   11  47  23   16    4  24   21    2  149  167  49     West
# 11      Ванкувер   12  46  18   11    4  28   25    2  154  183  39     West
# 12      Сан-Хосе   13  48  14   11    2  34   25    4  145  184  37     West
# 13       Аризона   14  47  15   12    1  32   27    3  123  170  35     West
# 14        Чикаго   15  45  14   10    4  31   27    2  108  163  32     West
# 15       Анахайм   16  47  13    5    5  34   29    3  113  199  31     West
# 16        Бостон    1  46  37   32    3   9    5    1  177   96  78     East
# 17      Каролина    2  46  29   22    4  17    9    6  151  124  66     East
# 18    Нью-Джерси    3  46  30   24    5  16   12    3  161  121  64     East
# 19       Торонто    4  47  28   24    4  19   11    7  158  125  64     East
# 20     Тампа-Бэй    5  45  29   23    5  16   15    0  163  135  59     East
# 21     Рейнджерс    6  46  25   20    3  21   14    5  145  123  57     East
# 22     Вашингтон    7  49  25   21    4  24   18    4  156  139  56     East
# 23     Питтсбург    8  46  23   20    2  23   15    8  148  138  54     East
# 24     Айлендерс    9  48  23   20    3  25   20    2  141  136  51     East
# 25       Флорида   10  48  23   22    0  25   20    4  163  163  51     East
# 26       Баффало   11  45  23   17    5  22   19    3  172  155  49     East
# 27   Филадельфия   12  48  20   19    1  28   21    6  133  155  47     East
# 28       Детройт   13  45  19   16    2  26   18    5  138  153  46     East
# 29        Оттава   14  46  20   15    4  26   23    3  133  152  43     East
# 30      Монреаль   15  47  20   12    4  27   24    3  125  171  43     East
# 31      Коламбус   16  46  14   10    3  32   30    1  119  180  30     East

# %%
table_guest = pd.read_json('data/table_guest.json')
table_guest
# Out:
#             team  pos  tm  tw  twr  two  tl  tlr  tlo   sg   cg  tp division
# 0       Виннипег    1  48  31   24    7  17   16    1  159  126  63     West
# 1         Даллас    2  48  28   25    2  20   13    5  167  124  63     West
# 2          Вегас    3  48  29   21    5  19   17    1  156  139  60     West
# 3          Сиэтл    4  46  27   22    5  19   14    3  166  144  59     West
# 11      Ванкувер   12  46  18   11    4  28   25    2  154  183  39     West
# 12      Сан-Хосе   13  48  14   11    2  34   25    4  145  184  37     West
# 13       Аризона   14  47  15   12    1  32   27    3  123  170  35     West
# 14        Чикаго   15  45  14   10    4  31   27    2  108  163  32     West
# 15       Анахайм   16  47  13    5    5  34   29    3  113  199  31     West
# 16        Бостон    1  46  37   32    3   9    5    1  177   96  78     East
# 17      Каролина    2  46  29   22    4  17    9    6  151  124  66     East
# 18    Нью-Джерси    3  46  30   24    5  16   12    3  161  121  64     East
# 19       Торонто    4  47  28   24    4  19   11    7  158  125  64     East
# 20     Тампа-Бэй    5  45  29   23    5  16   15    0  163  135  59     East
# 21     Рейнджерс    6  46  25   20    3  21   14    5  145  123  57     East
# 22     Вашингтон    7  49  25   21    4  24   18    4  156  139  56     East
# 23     Питтсбург    8  46  23   20    2  23   15    8  148  138  54     East
# 24     Айлендерс    9  48  23   20    3  25   20    2  141  136  51     East
# 25       Флорида   10  48  23   22    0  25   20    4  163  163  51     East
# 26       Баффало   11  45  23   17    5  22   19    3  172  155  49     East
# 27   Филадельфия   12  48  20   19    1  28   21    6  133  155  47     East
# 28       Детройт   13  45  19   16    2  26   18    5  138  153  46     East
# 29        Оттава   14  46  20   15    4  26   23    3  133  152  43     East
# 30      Монреаль   15  47  20   12    4  27   24    3  125  171  43     East
# 31      Коламбус   16  46  14   10    3  32   30    1  119  180  30     East

# %%
def longestCommonPrefix(strs) -> str:
        prefix = ''
        if not strs:
            return prefix
        for item in zip(*strs):
            print(item)
            if item[0] == item[1]:
                prefix += item[0]
            else:
                return prefix

# %%
strs = ["flower","flow","flight"]
longestCommonPrefix(strs)
# Out:
# ('f', 'f', 'f')
# ('l', 'l', 'l')
# ('o', 'o', 'i')
# ('w', 'w', 'g')

# %%
nums = [-1,0,1,2,-1,-4]
sorted(nums)
# Out:
# [-4, -1, -1, 0, 1, 2]

# %%
nums
# Out:
# [1, 2, 3, -5, -7, 2]

# %%
3  // 2
# Out:
# 1

# %%
first = {'~AA': 'Ysp5M8Dr', 'AD': '1674777600', 'ADE': '1674777600', 'AB': '3', 'CR': '3', 'AC': '10', 'CX': 'Монреаль', 'RW': '0', 'AX': '1', 'AO': '1674787437', 'BX': '-1', 'WL': '', 'WQ': '', 'WM': 'МОН', 'AE': 'Монреаль', 'FH': 'Монреаль', 'JA': '6mRmaUfq', 'AZ': '0', 'GRA': '0', 'AG': '3', 'AT': '3', 'BG': '0', 'BA': '1', 'BC': '2', 'BE': '0', 'OA': 'rmLcPRlC-UNwYOE6j.png', 'WN': 'ДЕТ', 'AF': 'Детройт', 'FK': 'Детройт', 'JB': 'KjViblAk', 'AS': '2', 'GRB': '0', 'AH': '4', 'AU': '3', 'BH': '1', 'BB': '1', 'BD': '2', 'BF': '0', 'OB': 'vipsZYT0-8zhLUqwC.png', 'AW': '1'}
second = {'~AA': '8YaDSZQt', 'AD': '1674777600', 'ADE': '1674777600', 'AB': '3', 'CR': '3', 'AC': '3', 'CX': 'Тампа-Бэй', 'RW': '0', 'AX': '1', 'AO': '1674787887', 'BX': '-1', 'WL': '', 'WQ': '', 'WM': 'ТАМ', 'AE': 'Тампа-Бэй', 'FH': 'Тампа-Бэй', 'JA': 'ju3Hj6vi', 'AS': '1', 'AZ': '1', 'GRA': '0', 'AG': '3', 'BA': '1', 'BC': '0', 'BE': '2', 'OA': 'dE1G4mne-UPCTXNVN.png', 'WN': 'БОС', 'AF': 'Бостон', 'FK': 'Бостон', 'JB': 'UV1LkQgc', 'GRB': '0', 'AH': '2', 'BB': '0', 'BD': '1', 'BF': '1', 'OB': 'UeHV59Pq-Kf1zyLao.png', 'AW': '1'}
third = {'~AA': 'nPbHRgtm', 'AD': '1674777600', 'ADE': '1674777600', 'AB': '3', 'CR': '3', 'AC': '11', 'CX': 'Вашингтон', 'RW': '0', 'AX': '1', 'AO': '1674787857', 'BX': '-1', 'WL': '', 'WQ': '', 'WN': 'ПИТ', 'AF': 'Питтсбург', 'FK': 'Питтсбург', 'JB': 'Gn0Tm4O9', 'AZ': '0', 'GRB': '0', 'AH': '2', 'AU': '2', 'BH': '0', 'BJ': '1', 'BB': '0', 'BD': '1', 'BF': '1', 'OB': 'nJ0Qys8k-nRjPT3hI.png', 'WM': 'ВАШ', 'AE': 'Вашингтон', 'FH': 'Вашингтон', 'JA': 'xd1Plp93', 'AS': '1', 'GRA': '0', 'AG': '3', 'AT': '2', 'BG': '0', 'BI': '2', 'BA': '1', 'BC': '0', 'BE': '1', 'OA': 'dIknNK96-lpfS7F4s.png', 'AW': '1'}

# %%
first.to_json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 first.to_json()
#
# AttributeError: 'dict' object has no attribute 'to_json'

# %%
with open("first.json", "w") as outfile:
    json.dump(first, outfile)

# %%
with open("second.json", "w") as outfile:
    json.dump(second, outfile)

# %%
with open("third.json", "w") as outfile:
    json.dump(third, outfile)

# %%
set(first.keys()) - set(second.keys())
# Out:
# {'AT', 'AU', 'BG', 'BH'}

# %%
set(second.keys())
# Out:
# {'AB',
#  'AC',
#  'AD',
#  'ADE',
#  'AE',
#  'AF',
#  'AG',
#  'AH',
#  'AO',
#  'AS',
#  'AW',
#  'AX',
#  'AZ',
#  'BA',
#  'BB',
#  'BC',
#  'BD',
#  'BE',
#  'BF',
#  'BX',
#  'CR',
#  'CX',
#  'FH',
#  'FK',
#  'GRA',
#  'GRB',
#  'JA',
#  'JB',
#  'OA',
#  'OB',
#  'RW',
#  'WL',
#  'WM',
#  'WN',
#  'WQ',
#  '~AA'}
