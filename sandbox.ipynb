# %%
import json
import pandas as pd
import os

# %%
cur_cwd = os.getcwd()
data_cwd = cur_cwd + '/data_6.2'
os.listdir(data_cwd)
# Out:
# ['next_tour_games.json',
#  'results_1.json',
#  'table_guest.json',
#  'table.json',
#  'table_home.json']

# %%
for item in os.listdir(data_cwd):
    print(pd.read_json(data_cwd + '/' + item))
# Out:
#      home_team guest_team                date  h_pos  h_sg  h_cg  h_tp  \
# 0  Филадельфия  Айлендерс 2023-02-07 03:00:00     22   142   162    51
# 1      Флорида  Тампа-Бэй 2023-02-07 03:00:00     21   178   183    54
# 2   Нью-Джерси   Ванкувер 2023-02-07 03:30:00      4   171   131    68
# 3    Рейнджерс    Калгари 2023-02-07 03:30:00     10   157   129    62
# 4       Даллас    Анахайм 2023-02-07 04:30:00      5   173   133    66
# 5      Аризона  Миннесота 2023-02-07 05:00:00     29   131   177    38
#
#    h_win_rate  h_lose_rate  h_win_rate_ft  ...  cg_per_game_home  \
# 0    0.411765     0.588235       0.952381  ...          3.458333
# 1    0.461538     0.538462       0.916667  ...          3.130435
# 2    0.653061     0.346939       0.750000  ...          2.800000
# 3    0.551020     0.448980       0.814815  ...          2.923077
# 4    0.549020     0.450980       0.892857  ...          2.916667
# 5    0.320000     0.680000       0.812500  ...          3.300000
#
# ...
